# %% [markdown]
# # Exercise 2: Tax Function

# %%
income=54780.0

if income <= 6000:
    tax = 0.0
elif income > 6000 and income <= 20000:
    tax = (income-6000)*0.17
elif income > 20000 and income <= 50000:
    tax = (income-20000)*0.30
elif income > 50000 and income <= 60000:
    tax = (income-50000)*0.42
elif income > 60000:
    tax = (income-60000)*0.47

print('tax(%1.2f) = %1.2f AUD' % (income,tax))
# Out:
# tax(54780.00) = 2007.60 AUD

# %%
# need to split up in years where nothing changes

# %%
year = 2000

if year == 2000 or 2001 or 2002:
    if income <= 6000:
        tax = 0.0
    elif income > 6000 and income <= 20000:
        tax = (income-6000)*0.17
    elif income > 20000 and income <= 50000:
        tax = (income-20000)*0.30
    elif income > 50000 and income <= 60000:
        tax = (income-50000)*0.42
    elif income > 60000:
        tax = (income-60000)*0.47
elif year =

    print('tax(%1.2f) = %1.2f AUD in %d' % (income,tax,year))
# Out:
# tax(54780.00) = 2007.60 AUD in 2000

# %%
def taxpaid(income, year):
    if year == 2000 or 2001 or 2002:
        if income <= 6000:
            tax = 0.0
        elif income > 6000 and income <= 20000:
            tax = (income-6000)*0.17
        elif income > 20000 and income <= 50000:
            tax = (income-20000)*0.30
        elif income > 50000 and income <= 60000:
            tax = (income-50000)*0.42
        elif income > 60000:
            tax = (income-60000)*0.47
    elif year == 2003:
        if income <= 6000:
            tax = 0.0
        elif income > 6000 and income <= 21600:
            tax = (income-6000)*0.17
        elif income > 21600 and income <= 52000:
            tax = (income-21600)*0.30
        elif income > 52000 and income <= 62500:
            tax = (income-52000)*0.42
        elif income > 62500:
            tax = (income-62500)*0.47
    elif year == 2004:
        if income <= 6000:
            tax = 0.0
        elif income > 6000 and income <= 21600:
            tax = (income-6000)*0.17
        elif income > 21600 and income <= 58000:
            tax = (income-21600)*0.30
        elif income > 58000 and income <= 70000:
            tax = (income-58000)*0.42
        elif income > 70000:
            tax = (income-70000)*0.47
    elif year == 2005:
        if income <= 6000:
            tax = 0.0
        elif income > 6000 and income <= 21600:
            tax = (income-6000)*0.15
        elif income > 21600 and income <= 63000:
            tax = (income-21600)*0.30
        elif income > 63000 and income <= 95000:
            tax = (income-63000)*0.42
        elif income > 95000:
            tax = (income-95000)*0.47
    elif year == 2006:
        if income <= 6000:
            tax = 0.0
        elif income > 6000 and income <= 25000:
            tax = (income-6000)*0.15
        elif income > 25000 and income <= 75000:
            tax = (income-25000)*0.30
        elif income > 75000 and income <= 150000:
            tax = (income-75000)*0.40
        elif income > 150000:
            tax = (income-150000)*0.45     
    elif year == 2007:
        if income <= 6000:
            tax = 0.0
        elif income > 6000 and income <= 30000:
            tax = (income-6000)*0.15
        elif income >30000 and income <= 75000:
            tax = (income-30000)*0.30
        elif income > 75000 and income <= 150000:
            tax = (income-75000)*0.40
        elif income > 150000:
            tax = (income-150000)*0.45   
    elif year == 2008:
        if income <= 6000:
            tax = 0.0
        elif income > 6000 and income <= 34000:
            tax = (income-6000)*0.15
        elif income >34000 and income <= 80000:
            tax = (income-34000)*0.30
        elif income > 80000 and income <= 180000:
            tax = (income-80000)*0.40
        elif income > 180000:
            tax = (income-180000)*0.45 
    elif year == 2009:
        if income <= 6000:
            tax = 0.0
        elif income > 6000 and income <= 35000:
            tax = (income-6000)*0.15
        elif income >35000 and income <= 80000:
            tax = (income-35000)*0.30
        elif income > 80000 and income <= 180000:
            tax = (income-80000)*0.38
        elif income > 180000:
            tax = (income-180000)*0.45 
    elif year == 2010 or 2011:
        if income <= 6000:
            tax = 0.0
        elif income > 6000 and income <= 37000:
            tax = (income-6000)*0.15
        elif income >37000 and income <= 80000:
            tax = (income-37000)*0.30
        elif income > 80000 and income <= 180000:
            tax = (income-80000)*0.37
        elif income > 180000:
            tax = (income-180000)*0.45 
    elif year == 2012 or 2013 or 2014 or 2015:
        if income <= 18200:
            tax = 0.0
        elif income > 18200 and income <= 37000:
            tax = (income-18200)*0.19
        elif income >37000 and income <= 80000:
            tax = (income-37000)*0.325
        elif income > 80000 and income <= 180000:
            tax = (income-80000)*0.37
        elif income > 180000:
            tax = (income-180000)*0.45
            
    return tax

# %%
print(taxpaid(54780.0, 2000))
# Out:
# 2007.6

# %%
print(taxpaid(500001, 2007))
# Out:
# 206800.47

# %%
print(taxpaid(82710, 2015))
# Out:
# 10673.699999999999

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [12, 8]



K = 250 #number of points in the income grid
max_inc = 250000 #maximum income
years = [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015]


inc = [k * 250000 / (K-1) for k in range(K)] # grid over income
tax = [0,]*K

for year in years:
    for j in range(K):
        income = inc[j]
        tax[j] = taxpaid(inc[j], year)
        plt.plot(inc, tax, label='year %d' % year)
plt.xlabel('Income ($)')
plt.ylabel('Tax ($)')
plt.show()

# %%
K = 250 #number of points in the income grid
max_inc = 250000 #maximum income
inc = [k * 250000 / (K-1) for k in range(K)] # grid over income
tax = [0,]*K

for year in [ for i in range()]:
    for j in range(K):
        income = inc[j]
        tax[j] = taxpaid(income, year)
    plt.plot(inc, tax, label="year %d" % year)
plt.xlabel('Income ($)')
plt.ylabel('Tax ($)')
plt.show()

# %% [markdown]
# # Exercise 3: Optimal Choice in the Bundle Good Market

# %%
class bundle_good():
    '''Class of bundled goods with well define arithmetics'''
    
    items = ('Opera A', 'Opera B', \
            'Ballet A', 'Ballet B', \
            'Symphonic orchestra concert', \
            'Rock opera', \
            'Operetta') # 7 different goods
    
    def __init__(self, quantities=[0,], price=0.0): #empty bundle of goods by default
        n = len(bundle_good.items)
        quantities = quantities[:n]
        if len(quantities) < n:
            quantities = quantities + [0] * (n - len(quantities))
        self.quantities = [int(q) for q in quantities]
        self.price = price 
        
    def __repr__(self):
        return "Bundle object %r with price %1.2f" % (self.quantities, self.price)
        
    def __add__(self, other): # addition for bundle goods
        if isinstance(other, bundle_good): #
            q = [x + y for x,y in zip(self.quantities, other.quantities)]
            p = self.price + other.price
            return bundle_good(q, p)
        elif isinstance(other, (int, float)):
            # adding a number changes the price
            return bundle_good(self.quantities, self.price + other)
        else:
            raise TypeError('Can only add bundle to bundle, or number to bundle price')
    
    def __sub__(self, other):
        if isinstance(other, bundle_good): #
            q = [x - y for x,y in zip(self.quantities, other.quantities)]
            p = self.price - other.price
            return bundle_good(q, p)
        elif isinstance(other, (int, float)):
            # adding a number changes the price
            return bundle_good(self.quantities, self.price - other)
        else:
            raise TypeError('Can only add bundle to bundle, or number to bundle price')
    
    def __mul__(self, num):
        if isinstance(num, int): #
            q = [x * num for x in self.quantities]
            p = self.price * num
            return bundle_good(q, p)
        else:
            raise TypeError('Can only add bundle to bundle, or number to bundle price')
    
    def __truediv__(self, num):
        if isinstance(num, int): #
            q = [x // num for x in self.quantities]
            if not all([x%num == 0 for x in self.quantities]): # list of true or false; all checks all elements of list
                raise ValueError('Can only divide such that the result has int quantities')
            p = self.price / num
            return bundle_good(q, p)
        else:
            raise TypeError('Can only add bundle to bundle, or number to bundle price')

# %%
# Available bundle goods
a = bundle_good([2,0,1,3,1,1,0],10.50)
b = bundle_good([0,5,0,4,2,2,2],15.36)
c = bundle_good([1,0,1,2,0,5,4],12.72)
market = [a,b,c]

# %%
import math

# %%
print(a.quantities[0])
# Out:
# 2

# %%
def u(x):
    return math.log(x.quantities[0] + 1) + ((x.quantities[1])**0.4 + 0.5 * (x.quantities[2]**0.4))**2.5 - \
    0.5 * math.log(x.quantities[3] + 1) - 0.2 * (x.quantities[4] * x.quantities[5])**0.2 + 2 * math.log(x.quantities[6] + 1)

# %%
def optim(budget, util, market):
    nn = 100
    m = -float('inf')
    for i in range(nn):
        for j in range(nn):
            for k in range(nn):
                bnd = a + b + c
                util = u(bnd)
                if bnd.price <= budget and m < util:
                    m = u(bnd)
                    x = bnd
    return x

# %%
optim(100, u, market)
# Out:
# Bundle object [3, 5, 2, 9, 3, 8, 6] with price 38.58

# %%
# optimization routine
def optim(budget,util,market):
    '''Returns the optimal combination of goods at the market, given the budget'''
    nn = 10 #heuristic for the maximum quantity to check
    # loop over all combination of three bundles to find max utility
    m = -float('inf') #initialize with negative infinity
    for i in range(nn):
        for j in range(nn):
            for k in range(nn):
                bnd = @@@  # combination of so many of each of the three bundled goods
                u = util(@@@)
                if bnd.price <= budget and m<u:
                    # found new maximum which is within the budget
                    m = @@@  # remember the new max utility
                    x = @@@  # remember the combination of bundle goods where max is attained
    return x #return the optimal combination of goods

def report(budget,util,x,market):
    '''Makes nice readable output'''
    @@@

# main program
for budget in [@@@]:
    x=optim(budget,u,market)
    report(budget,u,x,market)
